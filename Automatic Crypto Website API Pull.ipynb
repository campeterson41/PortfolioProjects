# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
# Out:
# /var/folders/3z/w9k0ygy51vd9zb45957lm81m0000gn/T/ipykernel_23441/606694711.py:4: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df
    
    #'/Users/cameronpeterson/Documents/Sorting folder/API.csv'
    
    if not os.path.isfile('/Users/cameronpeterson/Documents/Sorting folder/API.csv'):
        df.to_csv('/Users/cameronpeterson/Documents/Sorting folder/API.csv', header='column_names')
    else:
        df.to_csv('/Users/cameronpeterson/Documents/Sorting folder/API.csv', mode='a', header=False)

# %%
df = pd.read_csv('/Users/cameronpeterson/Documents/Sorting folder/API.csv')
df
# Out:
#     Unnamed: 0     id             name symbol             slug  \
# 0            0      1          Bitcoin    BTC          bitcoin
# 1            1   1027         Ethereum    ETH         ethereum
# 2            2    825      Tether USDt   USDT           tether
# 3            3     52              XRP    XRP              xrp
# 4            4   1839              BNB    BNB              bnb
# 5            5   3408         USD Coin   USDC         usd-coin
# 6            6   2010          Cardano    ADA          cardano
# 7            7   5426           Solana    SOL           solana
# 8            8     74         Dogecoin   DOGE         dogecoin
# 9            9   1958             TRON    TRX             tron
# 10          10   3890          Polygon  MATIC          polygon
# 11          11      2         Litecoin    LTC         litecoin
# 12          12   6636         Polkadot    DOT     polkadot-new
# 13          13  11419          Toncoin    TON          toncoin
# ...

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60)
exit()
# Out:
# /var/folders/3z/w9k0ygy51vd9zb45957lm81m0000gn/T/ipykernel_23441/3004874934.py:24: FutureWarning: The parsing of 'now' in pd.to_datetime without `utc=True` is deprecated. In a future version, this will match Timestamp('now') and Timestamp.now()
#   df['timestamp'] = pd.to_datetime('now')
# API Runner completed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[77], line 8
#       6     api_runner()
#       7     print('API Runner completed')
# ----> 8     sleep(60)
#       9 exit()
#
# KeyboardInterrupt:

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
# Coin trends over time
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#                  quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                             -0.14546                      -0.12672
# Ethereum                            -0.15990                      -0.49587
# Tether USDt                          0.02213                       0.04213
# XRP                                  0.17345                      -2.02954
# BNB                                 -0.15247                      -0.78263
# USD Coin                             0.02010                       0.01439
# Cardano                             -0.07698                      -0.63111
# Solana                              -0.47808                       0.42851
# Dogecoin                            -0.30396                      -2.87394
# TRON                                -0.13216                       4.82284
# Polygon                             -0.16892                      -0.74775
# ...

# %%
df4 = df3.stack()
df5 = df4.to_frame(name='values')
df5
# Out:
#                                                 values
# name
# Bitcoin         quote.USD.percent_change_1h   -0.14546
#                 quote.USD.percent_change_24h  -0.12672
#                 quote.USD.percent_change_7d   -1.49352
#                 quote.USD.percent_change_30d  -0.86367
#                 quote.USD.percent_change_60d   9.74319
#                 quote.USD.percent_change_90d   8.35907
# Ethereum        quote.USD.percent_change_1h   -0.15990
#                 quote.USD.percent_change_24h  -0.49587
#                 quote.USD.percent_change_7d   -2.37124
#                 quote.USD.percent_change_30d   0.07282
#                 quote.USD.percent_change_60d   2.06185
#                 quote.USD.percent_change_90d   1.28151
# Tether USDt     quote.USD.percent_change_1h    0.02213
#                 quote.USD.percent_change_24h   0.04213
#                 quote.USD.percent_change_7d    0.02164
#                 quote.USD.percent_change_30d   0.01234
# ...

# %%
index = pd.Index(range(90))
df6 = df5.reset_index()
df7 = df6.rename(columns={'level_1': 'percent_change'})

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')
